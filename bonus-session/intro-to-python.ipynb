# %% [markdown]
# # Jupyter notebook basics
#
# This notebook demonstrates how to use Jupyter notebooks:
#
# - Cell types (markdown vs code)
# - Running code
# - Execution order
# - Kernel behavior

# %%
print('This notebook is connected to a Python 3.10 kernel')
# Out:
# This notebook is connected to a Python 3.10 kernel

# %% [markdown]
# ## Execution order

# %%
user_name = 'George'

# %%
print(user_name)
# Out:
# George

# %%
user_name = 'Laura'

# %%
print(user_name)
# Out:
# Laura

# %% [markdown]
# ## Errors

# %%
print('This is a syntax error'
# Out:
#   File "/tmp/ipykernel_307/4255644718.py", line 1
#     print('This is a syntax error'
#          ^
# SyntaxError: '(' was never closed

# %%
print('The next line is a runtime error')
print(undefined_var)
# Out:
# The next line is a runtime error
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_307/2790303741.py in <cell line: 2>()
#       1 print('The next line is a runtime error')
# ----> 2 print(undefined_var)
#
# NameError: name 'undefined_var' is not defined
